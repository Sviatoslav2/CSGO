# %%
import sys
path = ".\\code"
sys.path.insert(1, path)

# %%
import model_interface
import config
import os
import pandas as pd

# %%
file_path = os.path.join(config.ConfigPath().path_to_data,"clean_data.csv")

# %%
data = pd.read_csv(file_path)[0:100]

# %%
model = model_interface.Model_interface()

# %%
model.fit_dataframe(data)

# %%
model.predict_df(data)
# Out:
#     Unnamed: 0   id  winner_side  ct_score  t_score  ct_players_alive  \
# 0            0    7            1         0        0                 5
# 1            1    8            1         0        0                 5
# 2            2    9            1         0        0                 5
# 3            3   10            1         0        0                 5
# 4            4   11            1         0        0                 5
# ..         ...  ...          ...       ...      ...               ...
# 95          95  120            0         0        3                 5
# 96          96  121            0         0        3                 5
# 97          97  122            0         0        3                 5
# 98          98  123            0         0        3                 5
# 99          99  124            0         0        3                 5
#
#     t_players_alive  ct_equipment_value_sum  t_equipment_value_sum  \
# ...
